# %%
import pandas as pd
import requests
import textract
import os
from bs4 import BeautifulSoup

# %%
current_url = 'https://datcp.wi.gov/Pages/Programs_Services/DataBreaches.aspx'

# %%
temp = pd.read_html(current_url)
rows_list = []
for breach in temp:
    row = {'Date Public Notified':breach.iloc[1][0],
           'Date of Breach':breach.iloc[1][1],
           'Company':breach.iloc[1][2],
           'Data Stolen':breach.iloc[1][3], 
           "Who's Affected":breach.iloc[3][0],
           'Details':breach.iloc[3][1]}
    rows_list.append(row)
wisconsin_now = pd.DataFrame(rows_list)

# %%
pre_current_year_url = 'https://datcp.wi.gov/Pages/Programs_Services/DataBreachArchive.aspx'
temp = pd.read_html(pre_current_year_url)
rows_list = []
for breach in temp:
    row = {'Date Public Notified':breach.iloc[1][0],
           'Date of Breach':breach.iloc[1][1],
           'Company':breach.iloc[1][2],
           'Data Stolen':breach.iloc[1][3], 
           "Who's Affected":breach.iloc[3][0],
           'Details':breach.iloc[3][1]}
    rows_list.append(row)
wisconsin_archive = pd.DataFrame(rows_list)

# %%
wisconsin = pd.concat([wisconsin_now, wisconsin_archive], ignore_index = True)

# %%
wisconsin
# Out:
#                                                Company  \
# 0                                   Caribou Coffee Co.
# 1                                    Bruegger’s Bagels
# 2                              Coffee and Bagel Brands
# 3                               Marriott International
# 4                                       Healthcare.gov
# 5                             Five Guys Holdings, Inc.
# 6                    Roadrunner Transportation Systems
# 7                                    T-Mobile USA Inc.
# 8                                     Adams County, WI
# 9                                    UnityPoint Health
# 10                                   ComplyRight, Inc.
# 11                                         Macy's Inc.
# 12                                Manitowoc County, WI
# 13   Educational Employees' Supplementary Retiremen...
# 14                                 RISE Wisconsin Inc.
# 15                      Access Group Education Lending
# 16                                   UnityPoint Health
# 17                                  Best Buy Co., Inc.
# 18                         Delta Airlines and [24]7.ai
# 19                                 Sears Holding Corp.
# 20   The Management Group working as a consultant f...
# 21   Hudson's Bay Company dba Saks Fifth Avenue, Sa...
# 22                        UnderArmour dba MyFitnessPal
# 23                      UW-Superior Alumni Association
# 24                                         Travelocity
# 25                 The Department of Homeland Security
# 26                                 Village of Nashotah
# 27                        Medical College of Wisconsin
# 28                                 Saris Cycling Group
# 29                              Uber Technologies Inc.
# ..                                                 ...
# 120                                             AT & T
# 121                            PF Chang’s China Bistro
# 122                                               eBay
# 123             Michaels Stores, Inc. & Aaron Brothers
# 124                                        Yahoo, Inc.
# 125                             Unity Health Insurance
# 126                                      Neiman Marcus
# 127                                           Snapchat
# 128                                       Target Corp.
# 129        Facebook, LinkedIn, Twitter, Gmail, & Yahoo
# 130                   Dynacare Laboratories, Milwaukee
# 131              Memorial Hospital of Lafayette County
# 132                     St. Mary’s Janesville Hospital
# 133                                              Adobe
# 134                                      Vendini, Inc.
# 135                                           Facebook
# 136                        TerraCom, Inc. ("TerraCom")
# 137                  Kirkwood Community College (ADPI)
# 138                                   Froedtert Health
# 139                                                NaN
# 140                                      Twitter, Inc.
# 141                        Skagit Valley Casino Resort
# 142              Advanced Data Processing, Inc. (ADPI)
# 143                          Pinnacle Foods Group, LLC
# 144                       Nationwide Insurance Company
# 145                              Alere Home Monitoring
# 146                        Department of Revenue (DOR)
# 147                                      Yahoo! Voices
# 148                                           LinkedIn
# 149                                  Under Armour Inc.
#
#                                            Data Stolen  \
# 0    Name, payment card number, expiration date, an...
# 1    Name, payment card number, expiration date, an...
# 2    Name, payment card number, expiration date, an...
# 3    Name, date of birth, address, phone number, em...
# 4    Name, date of birth, address, sex, last four d...
# 5    Name, date of birth, Social Security number, a...
# 6    Name, address, date of birth, and financial ac...
# 7    Name, phone number, email address, account num...
# 8    Name, Social Security number, Driver’s license...
# 9    Name, address, date of birth, Social Security ...
# 10   Name, address, telephone number, email address...
# 11   First and last names; full addresses; phone nu...
# 12   First name, last name, Social Security number,...
# 13      Names, addresses, and Social Security numbers.
# 14   Name, address, date of birth, Social Security ...
# 15   Names, driver's license numbers, and Social Se...
# 16   Social Security Numbers, dates of birth, medic...
# 17                           Payment card information.
# 18   Name, address, payment card number, CVV number...
# 19                           Payment card information.
# 20   Laptop which may have contained names, address...
# 21                                   Payment card data
# 22    Usernames, email addresses, and hashed passwords
# 23      Name, home address and Social Security number.
# 24                        Payment card number and CVV.
# 25   Names, Social Security numbers, dates of birth...
# 26   Names, addresses, dates of birth and drivers l...
# 27   Patients’ names, home addresses, dates of birt...
# 28       Names, addresses and Social Security numbers.
# 29   Names, phone numbers, email addresses and, in ...
# ..                                                 ...
# 120           Social Security Numbers and Call Records
# 121                    Credit & Debit Card Information
# 122  Customer names, account passwords, email addre...
# 123  Payment card information: Payment card number ...
# 124                              Usernames & passwords
# 125  Unity member number, date of birth, city of re...
# 126  Approximately 1.1 million customers who shoppe...
# 127                        Usernames and Phone Numbers
# 128  The breach involves the theft of information s...
# 129  Website login credentials (usernames) and pass...
# 130  Names, addresses, dates of birth, Social Secur...
# 131  Patient's name and account number, date(s) of ...
# 132  Patient name, date of birth, medical record an...
# 133  Customer names, passwords and payment (debit &...
# 134  Name, mailing address, email address, phone nu...
# 135             Email addresses and telephone numbers.
# 136  Name, Social Security Number, Date of Birth, A...
# 137  Names, birthdates, race, contact information a...
# 138  A computer virus may have allowed an unauthori...
# 139                                                NaN
# 140  Usernames, email addresses, and encrypted pass...
# 141  Stolen data may have included name, driver’s l...
# 142     Name, Date of Birth and Social Security Number
# 143  Names, Social Security Numbers, driver’s licen...
# 144  Individual’s Name and a combination of: Social...
# 145  Name, Address, Date of Birth, Social Security ...
# 146                            Social Security Numbers
# 147                        Email address and passwords
# 148  Access to approximately 6.5 million customer p...
# 149  Employee names, Social security numbers, Salar...
#
#                   Date Public Notified  \
# 0                    December 20, 2018
# 1                    December 20, 2018
# 2                    December 20, 2018
# 3                    November 30, 2018
# 4                     November 7, 2018
# 5                     November 2, 2018
# 6                      October 8, 2018
# 143  Pinnacle Foods learned that an employee’s lapt...
# 144  Nationwide Insurance Company confirmed that on...
# 145  A car belonging to an Alere Home Monitoring em...
# 146  The Department of Revenue (DOR) has had a data...
# 147  Yahoo confirmed on Thursday, July 12, 2012 tha...
# 148  On June 6, 2012, LinkedIn confirmed a security...
# 149  An unencrypted thumb drive containing payroll ...
#
#                                         Who's Affected
# 0    Unknown number of affected individuals includi...
# 1    Unknown number of affected individuals includi...
# 2    Unknown number of affected individuals includi...
# 3    Approximately 500 million affected individuals...
# 4    75,000 affected individuals including an unkno...
# 5    Approximately 19,000 affected individuals incl...
# 6    Unknown number of affected individuals includi...
# 7    Unknown number of affected individuals includi...
# 8    258,120 affected individuals, an unknown numbe...
# 9    Approximately 1.4 million individuals affected...
# 10       662,000 including 12,155 Wisconsin residents.
# 11   Unknown – it is undetermined at this time the ...
# 12              Approximately 450 Wisconsin residents.
# 13   3,332 affected individuals including 9 Wiscons...
# 14   3,731 affected individuals, according to RISE ...
# 15   Approximately 16,500 borrowers (unknown if any...
# 16   Approximately 16,000 individuals affected, an ...
# 17   An unknown number of Best Buy customers, wheth...
# 18             Unknown number of affected individuals.
# 19   Less than 100,000 customers who completed an o...
# 20                      779 IRIS Program participants.
# 21   Consumers who used credit or debit cards to ma...
# 22            Approximately 150 million user accounts.
# 23   1,758 Wisconsin residents who were members of ...
# 24   Three Wisconsin residents who used the travel ...
# 25   Approximately 246,167 current and former feder...
# 26   Between 980 and 1000 Wisconsin residents who w...
# 27   7,289 Wisconsin residents who were patients of...
# 28   An unknown number of Wisconsin residents who a...
# 29   2,703 Wisconsin residents who were employees o...
# ..                                                 ...
# 120                                   AT & T Customers
# 121  Consumers who used their debit and/or credit c...
# 122  On Wednesday, May 21, 2014 eBay announced that...
# 123  Approximately 3 million Michael’s Stores custo...
# 124                            Yahoo, Inc. email users
# 125  41,437 Unity Health Insurance members may have...
# 126  Neiman Marcus confirmed Saturday that its cust...
# 127          Approximately 4.6 million Snapchat users.
# 128  Approximately 40 million customers who made pu...
# 129  Approximately two million Facebook, LinkedIn, ...
# 130  On October 22, 2013, Dynacare learned that a f...
# 131  Patients who received care/services at Memoria...
# 132  They have identified 629 patients who may have...
# 133         Approximately 2.9 million Adobe customers.
# 134  Vendini provides box office and online ticketi...
# 135  Approximately 6 million Facebook users had ema...
# 136  The data accessed belonged to 150,000 applican...
# 137  Individuals who applied for college-credit cla...
# 138  Although there was no evidence found that any ...
# 139                                     Who’s Affected
# 140               Approximately 250,000 Twitter users.
# 141  Individual’s whose information may have been e...
# 142  Individuals whose information may have been ex...
# 143  Individual whose information may have been exp...
# 144  Nationwide’s records indicate that the informa...
# 145  More than 100,000; among those affected includ...
# 146  The first seller listed on the real estate pro...
# 147  This affects those who use: Yahoo!, Gmail, MSN...
# 148  About 6.5 million LinkedIn users were affected...
# 149  Unspecified number of employees. Under Armour ...
#
# [150 rows x 6 columns]
