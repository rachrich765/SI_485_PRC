# %%
import wikipedia
import pandas as pd

# %%
x = wikipedia.page("Facebook")
url = x.url

# %%
info_box = pd.read_html(url, attrs = {'class':'infobox'})

# %%
info_box[0]
# Out:
#                                                     0  \
# 0                                                 NaN
# 1   Mark Zuckerberg's profile (viewed from the log...
# 2                                    Type of business
# 3                                        Type of site
# 4                                        Available in
# 5                                           Traded as
# 6                                             Founded
# 7                                        Headquarters
# 8                                         Coordinates
# 9                                         Area served
# 10                                         Founder(s)
# 11                                         Key people
# 12                                           Industry
# 13                                           Products
# 14                                            Revenue
# 15                                   Operating income
# 16                                         Net income
# 17                                       Total assets
# 18                                       Total equity
# 19                                          Employees
# 20                                       Subsidiaries
# 21                                            Website
# 22                                         Alexa rank
# 23                                       Registration
# 24                                              Users
# 25                                     Current status
# 26                                         Written in
#
#                                                     1
# 0                                                 NaN
# 1                                                 NaN
# 2                                              Public
# 3                           Social networking service
# 4                                  Multilingual (140)
# 5   NASDAQ: FB (Class A)NASDAQ-100 componentS&P 10...
# 6   February 4, 2004; 15 years ago in Cambridge, M...
# 7   1 Hacker Way(aka 1601 Willow Road)Menlo Park, ...
# 8   37°29′05″N 122°08′54″W﻿ / ﻿37.4848°N 122.1484°...
# 9   United States (2004–present)Worldwide, except ...
# 10  Mark ZuckerbergEduardo SaverinAndrew McCollumD...
# 11  Mark Zuckerberg(Chairman and CEO)Sheryl Sandbe...
# 12                                           Internet
# 13                                     MessengerWatch
# 14                        US$40.653 billion (2017)[2]
# 15                        US$20.203 billion (2017)[2]
# 16                        US$15.934 billion (2017)[2]
# 17                        US$84.524 billion (2017)[2]
# 18                        US$74.347 billion (2017)[2]
# 19                          30,275 (June 30, 2018)[3]
# 20                         InstagramWhatsAppOculus VR
# 21  www.facebook.comwww.fb.comfacebookcorewwwi.oni...
# 22                               3 (February 2019)[4]
# 23                                           Required
# 24    2.2 billion monthly active users (January 2018)
# 25                                             Active
# 26                        C++, PHP (as HHVM),[5] D[6]

# %%
def get_info(company_name):
    industry, website, products, parent = '','','',''
    x = wikipedia.page(company_name)
    url = x.url
    info_box = pd.read_html(url, attrs = {'class':'infobox'})[0].set_index(0)
    
    #FILL IN TO EXTRACT INFO
    
    return industry, website, products, parent

# %%
print (get_info("Qualtrics"))
# Out:
#                                                                      1
# 0
# NaN                                                                NaN
# Type                                                           Private
# Industry                                         Experience Management
# Founded                                             2002; 17 years ago
# Founders              Scott M. SmithRyan SmithJared SmithStuart Orgill
# Headquarters         Provo, Utah, U.S. Seattle, Washington, U.S.Oth...
# Key people           Ryan Smith, CEO[1] Co-founder, Scott M. Smith,...
# Products             Qualtrics XM Platform, Qualtrics Research Core...
# Number of employees                                             2,100+
# Parent                                                             SAP
# Website                                                  Qualtrics.com
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-55797e89dc1e> in <module>
# ----> 1 print (get_info("Qualtrics"))
#
# <ipython-input-32-1e49d442a38e> in get_info(company_name)
#       5     info_box = pd.read_html(url, attrs = {'class':'infobox'})[0].set_index(0)
#       6     print (info_box)
# ----> 7     if info_box.iloc('Website'):
#       8         website = info_box.loc('Website')
#       9     return industry, website, products, parent
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     373                 pass
#     374         raise ValueError('No axis named {0} for object type {1}'
# --> 375                          .format(axis, type(self)))
#     376
#     377     def _get_axis_name(self, axis):
#
# ValueError: No axis named Website for object type <class 'pandas.core.frame.DataFrame'>
