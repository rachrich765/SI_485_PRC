# %% [markdown]
# THINGS TO GET:
# - industry
# - type
# - website

# %%
import wikipedia

# %%
wikipedia.prop("Qualtrics")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-581d0e7e5334> in <module>
# ----> 1 wikipedia.prop("Qualtrics")
#
# AttributeError: module 'wikipedia' has no attribute 'prop'

# %%
wikipedia.summary("Qualtrics")
# Out:
# 'Qualtrics is a privately held experience management company, with co-headquarters in Provo, Utah and Seattle, Washington, in the United States. The company was founded in 2002 by Scott M. Smith, Ryan Smith, Jared Smith and Stuart Orgill.Qualtrics is a subscription software for collecting and analyzing data for market research, customer satisfaction and loyalty, product and concept testing, employee evaluations and website feedback.On November 11, 2018 it was announced that Qualtrics would be acquired by SAP. The acquisition is expected to close in the first half of 2019.'

# %%
x = wikipedia.page("Qualtrics")

# %%
x.sections
# Out:
# []

# %%
import wikipediaapi

# %%
wiki_wiki = wikipediaapi.Wikipedia('en')

page_py = wiki_wiki.page('Qualtrics')

# %%
p_wiki = wiki_wiki.page("Qualtrics")
print(p_wiki.text)
# Out:
# Qualtrics is a privately held experience management company, with co-headquarters in Provo, Utah and Seattle, Washington, in the United States. The company was founded in 2002 by Scott M. Smith, Ryan Smith, Jared Smith and Stuart Orgill.Qualtrics is a subscription software for collecting and analyzing data for market research, customer satisfaction and loyalty, product and concept testing, employee evaluations and website feedback.On November 11, 2018 it was announced that Qualtrics would be acquired by SAP. The acquisition is expected to close in the first half of 2019.
#
# History
# Funding & Valuation
# In 2012, the company received a $70 million investment from Sequoia Capital and Accel Partners, generally considered two of the top venture capital firms in the country.  It was the largest joint investment to date by these two firms.  In September 2014, Sequoia Capital and Accel Partners returned in Series B funding, led by Insight Venture Partners worth $150 million, a record for a Utah-based company. In April 2017 Qualtrics received a Series C of $180 million by funded by returning investors Accel, Sequoia Capital, and Insight Venture Partners. The Series C was raised at a $2.3 billion pre-money valuation.Over its lifetime, Qualtrics has raised a total of $400 million from Accel, Insight Venture Partners and Sequoia Capital.
#
# Filing for IPO
# On October 19, 2018 Qualtrics filed their S-1 registration statement with the intention of raising gross proceeds of $200 million through an Initial Public Offering (IPO) of its Class B shares. The company will list under the NASDAQ under the ticker "XM" in reference to their flagship experience management product, the Qualtrics XM Platform.
# When it was announced in November 2018 Qualtrics would be acquired by SAP (NYSE: SAP) plans for an IPO were scrapped.
#
# Ranking
# In 2016, Qualtrics was ranked #12 on the Forbes Cloud 100 list, moving to #6 in 2017.
#
# Revenue
# Qualtrics reported revenue of $190.6 million in 2016 and $289.9 million in 2017 representing year over year growth of 52%. In 2016, Qualtrics reported an overall net loss of $12 million with free cash flow of $3.4 million. In 2017, Qualtrics reported a $2.6 million net profit with free cash flow of $21.3 million.
#
# Acquisitions
# In May 2016 Qualtrics acquired statistical analysis startup Statwing for an undisclosed sum. Statwing was a San Francisco-based company that created point-and-click software for advanced statistical analysis.In April 2018 Qualtrics acquired Delighted for an undisclosed sum. Delighted had over 1500 customers at the time of acquisition.In June 2018, Tango Card, a digital rewards and incentives provider collaborated with Qualtrics to improve management of digital incentives and distribution of gift cards.
#
# Acquisition by SAP SE
# In November 2018, it was announced that it would be acquired by SAP. SAP will acquire all outstanding shares of Qualtrics for $8 billion USD in an all cash deal. SAP secured €7 billion in financing. At the time it was announced, the Qualtrics acquisition will be SAP's second-biggest purchase ever behind the $8.3 billion acquisition of travel and expense management firm Concur in 2014.
#
# Research
# Quantitative statistical analysis performed with Qualtrics is cited in a number of professional and academic journals. Qualtrics became the first employee management platform measuring employee experiences through key metrics powered by predictive intelligence.
#
# References
# External links
# Official website

# %%
p_wiki.sections
# Out:
# [Section: History (1):
#
#  Subsections (6):
#  Section: Funding & Valuation (2):
#  In 2012, the company received a $70 million investment from Sequoia Capital and Accel Partners, generally considered two of the top venture capital firms in the country.  It was the largest joint investment to date by these two firms.  In September 2014, Sequoia Capital and Accel Partners returned in Series B funding, led by Insight Venture Partners worth $150 million, a record for a Utah-based company. In April 2017 Qualtrics received a Series C of $180 million by funded by returning investors Accel, Sequoia Capital, and Insight Venture Partners. The Series C was raised at a $2.3 billion pre-money valuation.Over its lifetime, Qualtrics has raised a total of $400 million from Accel, Insight Venture Partners and Sequoia Capital.
#  Subsections (0):
#
#  Section: Filing for IPO (2):
#  On October 19, 2018 Qualtrics filed their S-1 registration statement with the intention of raising gross proceeds of $200 million through an Initial Public Offering (IPO) of its Class B shares. The company will list under the NASDAQ under the ticker "XM" in reference to their flagship experience management product, the Qualtrics XM Platform.
#  When it was announced in November 2018 Qualtrics would be acquired by SAP (NYSE: SAP) plans for an IPO were scrapped.
#  Subsections (0):
#
#  Section: Ranking (2):
#  In 2016, Qualtrics was ranked #12 on the Forbes Cloud 100 list, moving to #6 in 2017.
#  Subsections (0):
#
#  Section: Revenue (2):
#  Qualtrics reported revenue of $190.6 million in 2016 and $289.9 million in 2017 representing year over year growth of 52%. In 2016, Qualtrics reported an overall net loss of $12 million with free cash flow of $3.4 million. In 2017, Qualtrics reported a $2.6 million net profit with free cash flow of $21.3 million.
#  Subsections (0):
#
#  Section: Acquisitions (2):
#  In May 2016 Qualtrics acquired statistical analysis startup Statwing for an undisclosed sum. Statwing was a San Francisco-based company that created point-and-click software for advanced statistical analysis.In April 2018 Qualtrics acquired Delighted for an undisclosed sum. Delighted had over 1500 customers at the time of acquisition.In June 2018, Tango Card, a digital rewards and incentives provider collaborated with Qualtrics to improve management of digital incentives and distribution of gift cards.
#  Subsections (0):
#
#  Section: Acquisition by SAP SE (2):
#  In November 2018, it was announced that it would be acquired by SAP. SAP will acquire all outstanding shares of Qualtrics for $8 billion USD in an all cash deal. SAP secured €7 billion in financing. At the time it was announced, the Qualtrics acquisition will be SAP's second-biggest purchase ever behind the $8.3 billion acquisition of travel and expense management firm Concur in 2014.
#  Subsections (0):, Section: Research (1):
#  Quantitative statistical analysis performed with Qualtrics is cited in a number of professional and academic journals. Qualtrics became the first employee management platform measuring employee experiences through key metrics powered by predictive intelligence.
#  Subsections (0):, Section: References (1):
#
#  Subsections (0):, Section: External links (1):
#  Official website
#  Subsections (0):]

# %%
import requests 

S = requests.Session()

URL = "https://en.wikipedia.org/w/api.php"

TITLE = "Qualtrics"

PARAMS = {
    'action': "parse",
    'page': TITLE,
    'format': "json"
}

R = S.get(url=URL, params=PARAMS)
DATA = R.json()
DATA['parse']

#print(DATA)
# Out:
# {'title': 'Qualtrics',
#  'pageid': 24503612,
#  'revid': 879452946,
#  'text': {'*': '<div class="mw-parser-output"><table class="infobox vcard" style="width:22em"><caption class="fn org">Qualtrics International Inc.</caption><tbody><tr><td colspan="2" class="logo" style="text-align:center"><a href="/wiki/File:Qualtrics_logo.svg" class="image"><img alt="Qualtrics logo.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Qualtrics_logo.svg/200px-Qualtrics_logo.svg.png" decoding="async" width="200" height="72" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Qualtrics_logo.svg/300px-Qualtrics_logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Qualtrics_logo.svg/400px-Qualtrics_logo.svg.png 2x" data-file-width="150" data-file-height="54" /></a></td></tr><tr><th scope="row" style="padding-right:0.5em;"><div style="padding:0.1em 0;line-height:1.2em;"><a href="/wiki/List_of_legal_entity_types_by_country" title="List of legal entity types by country">Type</a></div></th><td class="category" style="line-height:1.35em;"><a href="/wiki/Private_Company" class="mw-redirect" title="Private Company">Private</a></td></tr><tr><th scope="row" style="padding-right:0.5em;">Industry</th><td class="category" style="line-height:1.35em;">Experience Management</td></tr><tr><th scope="row" style="padding-right:0.5em;">Founded</th><td style="line-height:1.35em;">2002<span class="noprint">&#59;&#32;17&#160;years ago</span><span style="display:none">&#160;(<span class="bday dtstart published updated">2002</span>)</span></td></tr><tr><th scope="row" style="padding-right:0.5em;">Founders</th><td class="agent" style="line-height:1.35em;">Scott M. Smith<br />Ryan Smith<br />Jared Smith<br />Stuart Orgill</td></tr><tr><th scope="row" style="padding-right:0.5em;">Headquarters</th><td class="label" style="line-height:1.35em;"><a href="/wiki/Provo,_Utah" title="Provo, Utah">Provo, Utah</a>, <a href="/wiki/United_States" title="United States">U.S.</a><br /> <a href="/wiki/Seattle,_Washington" class="mw-redirect" title="Seattle, Washington">Seattle, Washington</a>, U.S.<br />Other offices: Dublin, Ireland<br />Sydney, NSW, Australia<br />London, England, U.K.<br />Munich, Germany<br />Melbourne, Vic, Australia<br />Washington, D.C., U.S.<br />Dallas, Texas, U.S.</td></tr><tr><th scope="row" style="padding-right:0.5em;"><div style="padding:0.1em 0;line-height:1.2em;">Key people</div></th><td class="agent" style="line-height:1.35em;"><b>Ryan Smith,</b> CEO<sup id="cite_ref-USAToday2012Scott_1-0" class="reference"><a href="#cite_note-USAToday2012Scott-1">&#91;1&#93;</a></sup> Co-founder, <b>Scott M. Smith,</b> Co-founder, <b>Jared Smith,</b> Co-founder, and <b>Stuart Orgill,</b> Co-founder</td></tr><tr><th scope="row" style="padding-right:0.5em;">Products</th><td style="line-height:1.35em;">Qualtrics XM Platform, Qualtrics Research Core, Customer Experience, Employee Experience, Product Experience, Brand Experience, Online Sample</td></tr><tr><th scope="row" style="padding-right:0.5em;"><div style="padding:0.1em 0;line-height:1.2em;">Number of employees</div></th><td style="line-height:1.35em;">2,100+</td></tr><tr><th scope="row" style="padding-right:0.5em;">Website</th><td style="line-height:1.35em;"><a rel="nofollow" class="external text" href="http://www.qualtrics.com/">Qualtrics.com</a></td></tr></tbody></table>\n<p><b>Qualtrics</b> is a privately held experience management company, with co-headquarters in <a href="/wiki/Provo,_Utah" title="Provo, Utah">Provo, Utah</a> and <a href="/wiki/Seattle,_Washington" class="mw-redirect" title="Seattle, Washington">Seattle, Washington</a>, in the United States. The company was founded in 2002 by Scott M. Smith, Ryan Smith, Jared Smith and Stuart Orgill.<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">&#91;2&#93;</a></sup>\n</p><p>Qualtrics is a subscription software for collecting and analyzing data<sup id="cite_ref-USAToday2012Scott_1-1" class="reference"><a href="#cite_note-USAToday2012Scott-1">&#91;1&#93;</a></sup> for market research, c ...
#  'langlinks': [{'lang': 'ko',
#    'url': 'https://ko.wikipedia.org/wiki/%ED%80%BC%ED%8A%B8%EB%A6%AD%EC%8A%A4',
#    'langname': 'Korean',
#    'autonym': '한국어',
#    '*': '퀼트릭스'}],
#  'categories': [{'sortkey': '',
#    'hidden': '',
#    '*': 'All_articles_with_dead_external_links'},
#   {'sortkey': '',
#    'hidden': '',
#    '*': 'Articles_with_dead_external_links_from_July_2016'},
#   {'sortkey': '',
#    'hidden': '',
#    '*': 'Articles_with_permanently_dead_external_links'},
#   {'sortkey': '',
#    'hidden': '',
#    '*': 'CS1_maint:_Multiple_names:_authors_list'},
#   {'sortkey': '', 'hidden': '', '*': 'Commons_category_link_from_Wikidata'},
#   {'sortkey': '', '*': 'Software_companies_based_in_Utah'},
#   {'sortkey': '', '*': 'Companies_based_in_Provo,_Utah'},
#   {'sortkey': '', '*': 'Polling_companies'},
#   {'sortkey': '', '*': 'Companies_established_in_2002'},
#   {'sortkey': '', '*': 'Statistical_survey_software'},
#   {'sortkey': '', '*': 'Web_applications'},
#   {'sortkey': '', '*': 'Cloud_computing_providers'},
#   {'sortkey': '', '*': 'Cloud_applications'},
#   {'sortkey': '', '*': 'Service-oriented_(business_computing)'},
#   {'sortkey': '', '*': 'Marketing_research_companies_of_the_United_States'},
#   {'sortkey': '', '*': 'Market_research'},
#   {'sortkey': '', '*': '2002_establishments_in_Utah'},
#   {'sortkey': '', '*': 'Companies_based_in_Seattle'},
#   {'sortkey': '', '*': 'Announced_technology_acquisitions'},
#   {'sortkey': '', '*': 'SAP_SE_acquisitions'}],
#  'links': [{'ns': 14,
#    'exists': '',
#    '*': 'Category:Articles with dead external links from July 2016'},
#   {'ns': 14,
#    'exists': '',
#    '*': 'Category:CS1 maint: Multiple names: authors list'},
#   {'ns': 10, 'exists': '', '*': 'Template:Survey data collection'},
#   {'ns': 10, 'exists': '', '*': 'Template:Provo, Utah'},
#   {'ns': 0, 'exists': '', '*': 'AM broadcasting'},
#   {'ns': 0, 'exists': '', '*': 'Accel Partners'},
#   {'ns': 0, 'exists': '', '*': 'Action Target'},
#   {'ns': 0, 'exists': '', '*': 'Alpine Air Express'},
#   {'ns': 0, 'exists': '', '*': "America's Freedom Festival at Provo"},
#   {'ns': 0, 'exists': '', '*': 'Aquaveo'},
#   {'ns': 0, 'exists': '', '*': 'BYU Museum of Paleontology'},
#   {'ns': 0, 'exists': '', '*': 'BYU Television International'},
#   {'ns': 0, 'exists': '', '*': 'BYUtv'},
#   {'ns': 0, 'exists': '', '*': 'Bluehost'},
#   {'ns': 0, 'exists': '', '*': 'Bridal Veil Falls (Utah)'},
#   {'ns': 0, 'exists': '', '*': 'Brigham Young University'},
#   {'ns': 0, 'exists': '', '*': 'Brigham Young University Arboretum'},
#   {'ns': 0,
#    'exists': '',
#    '*': 'Brigham Young University Centennial Carillon Tower'},
#   {'ns': 0, 'exists': '', '*': 'Brigham Young University Museum of Art'},
#   {'ns': 0,
#    'exists': '',
#    '*': 'Brigham Young University Museum of Peoples and Cultures'},
#   {'ns': 0, 'exists': '', '*': 'California Zephyr (Amtrak train)'},
#   {'ns': 0, 'exists': '', '*': 'Charles E. Davies House'},
#   {'ns': 0, 'exists': '', '*': 'Charles E. Loose House'},
#   {'ns': 0, 'exists': '', '*': 'Clark-Taylor House'},
#   {'ns': 0, 'exists': '', '*': 'Combustion Resources'},
#   {'ns': 0, 'exists': '', '*': 'Community Action Services and Food Bank'},
#   {'ns': 0, 'exists': '', '*': 'Covey Center for the Arts'},
#   {'ns': 0, 'exists': '', '*': 'CreateSurvey'},
#   {'ns': 0, 'exists': '', '*': 'Daily Herald (Utah)'},
#   {'ns': 0, 'exists': '', '*': 'Dr. Samuel H. Allen House and Carriage House'},
#   {'ns': 0, 'exists': '', '*': 'Empower Playgrounds'},
#   {'ns': 0, 'exists': '', '*': 'FM radio'},
#   {'ns': 0, 'exists': '', '*': 'Festival Latinoamericano'},
#   {'ns': 0, 'exists': '', '*': 'Flag of Provo, Utah'},
#   {'ns': 0, 'exists': '', '*': 'Forbes'},
#   {'ns': 0, 'exists': '', '*': 'Fort Utah'},
#   {'ns': 0, 'exists': '', '*': 'Franklin S. Harris Fine Arts Center'},
#   {'ns': 0, 'exists': '', '*': 'FrontRunner'},
#   {'ns': 0, 'exists': '', '*': 'George Angus and Martha Ansil Beebe House'},
#   {'ns': 0, 'exists': '', '*': 'George M. Brown House'},
#   {'ns': 0, 'exists': '', '*': 'George Taylor Jr. House'},
#   {'ns': 0, 'exists': '', '*': 'Google Consumer Surveys'},
#   {'ns': 0, 'exists': '', '*': 'Google Fiber'},
#   {'ns': 0, 'exists': '', '*': 'Google Forms'},
#   {'ns': 0, 'exists': '', '*': 'Google Opinion Rewards'},
#   {'ns': 0, 'exists': '', '*': 'Hannah Maria Libby Smith House'},
#   {'ns': 0, 'exists': '', '*': 'Harvey H. Cluff House'},
#   {'ns': 0, 'exists': '', '*': 'Hines Mansion'},
#   {'ns': 0, 'exists': '', '*': 'Hotel Roberts (Provo, Utah)'},
#   {'ns': 0, 'exists': '', '*': 'Insight Venture Partners'},
#   {'ns': 0, 'exists': '', '*': 'International Standard Book Number'},
#   {'ns': 0, 'exists': '', '*': 'Interstate 15 in Utah'},
#   {'ns': 0, 'exists': '', '*': 'Jesse Knight House'},
#   {'ns': 0, 'exists': '', '*': 'John E. Booth House'},
#   {'ns': 0, 'exists': '', '*': 'John R. Twelves House'},
#   {'ns': 0, 'exists': '', '*': 'Johnson–Hansen House'},
#   {'ns': 0, 'exists': '', '*': 'Joseph H. Frisby House'},
#   {'ns': 0, 'exists': '', '*': 'KBYU-FM'},
#   {'ns': 0, 'exists': '', '*': 'KBYU-TV'},
#   {'ns': 0, 'exists': '', '*': 'KENZ (FM)'},
#   {'ns': 0, 'exists': '', '*': 'KEYY'},
#   {'ns': 0, 'exists': '', '*': 'KOVO'},
#   {'ns': 0, 'exists': '', '*': 'KSRR'},
#   {'ns': 0, 'exists': '', '*': 'KUPX-TV'},
#   {'ns': 0, 'exists': '', '*': 'KUTH-DT'},
#   {'ns': 0, 'exists': '', '*': 'KXRK'},
#   {'ns': 0, 'exists': '', '*': 'Knight-Allen House'},
#   {'ns': 0, 'exists': '', '*': 'Knight-Mangum House'},
#   {'ns': 0, 'exists': '', '*': 'Knight Block'},
#   {'ns': 0, 'exists': '', '*': 'LaVell Edwards Stadium'},
#   {'ns': 0, 'exists': '', '*': 'Lakeview Tithing Office'},
#   {'ns': 0, 'exists': '', '*': 'Larry H. Miller Field'},
#   {'ns': 0, 'exists': '', '*': 'Lewis Terrace'},
#   {'ns': 0, 'exists': '', '*': 'List of legal entity types by country'},
#   {'ns': 0, 'exists': '', '*': 'List of people from Provo, Utah'},
#   {'ns': 0, 'exists': '', '*': 'Maeser Elementary'},
#   {'ns': 0, 'exists': '', '*': 'Marriott Center'},
#   {'ns': 0, 'exists': '', '*': 'Missionary Training Center'},
#   {'ns': 0, 'exists': '', '*': 'Monte L. Bean Life Science Museum'},
#   {'ns': 0, 'exists': '', '*': 'Morinda, Inc.'},
#   {'ns': 0, 'exists': '', '*': 'New Play Project'},
#   {'ns': 0, 'exists': '', '*': 'North American Arms'},
#   {'ns': 0, 'exists': '', '*': 'Novell'},
#   {'ns': 0, 'exists': '', '*': 'Nu Skin Enterprises'},
#   {'ns': 0, 'exists': '', '*': 'Olmsted Station Powerhouse'},
#   {'ns': 0, 'exists': '', '*': 'Peaks Ice Arena'},
#   {'ns': 0, 'exists': '', '*': 'Peter Wentz House'},
#   {'ns': 0, 'exists': '', '*': 'Private Company'},
#   {'ns': 0, 'exists': '', '*': 'ProofPilot'},
#   {'ns': 0, 'exists': '', '*': 'Provo, Utah'},
#   {'ns': 0, 'exists': '', '*': 'Provo Canyon'},
#   {'ns': 0, 'exists': '', '*': 'Provo Canyon Guard Quarters'},
#   {'ns': 0, 'exists': '', '*': 'Provo City Center Temple'},
#   {'ns': 0, 'exists': '', '*': 'Provo City Library'},
#   {'ns': 0, 'exists': '', '*': 'Provo City School District'},
#   {'ns': 0, 'exists': '', '*': 'Provo Downtown Historic District'},
#   {'ns': 0, 'exists': '', '*': 'Provo East Central Historic District'},
#   {'ns': 0, 'exists': '', '*': 'Provo High School'},
#   {'ns': 0, 'exists': '', '*': 'Provo Municipal Airport'},
#   {'ns': 0, 'exists': '', '*': 'Provo Peak'},
#   {'ns': 0, 'exists': '', '*': 'Provo River'},
#   {'ns': 0, 'exists': '', '*': 'Provo Tabernacle'},
#   {'ns': 0, 'exists': '', '*': 'Provo Third Ward Chapel and Amusement Hall'},
#   {'ns': 0, 'exists': '', '*': 'Provo Utah Temple'},
#   {'ns': 0, 'exists': '', '*': 'Provo West Co-op'},
#   {'ns': 0, 'exists': '', '*': 'Provo station (Amtrak)'},
#   {'ns': 0, 'exists': '', '*': 'Provo station (Utah Transit Authority)'},
#   {'ns': 0, 'exists': '', '*': 'QuestBack'},
#   {'ns': 0,
#    'exists': '',
#    '*': 'Recreation Center for the Utah State Hospital'},
#   {'ns': 0, 'exists': '', '*': 'Reed O. Smoot House'},
#   {'ns': 0, 'exists': '', '*': 'Revere Health'},
#   {'ns': 0,
#    'exists': '',
#    '*': 'Rocky Mountain University of Health Professions'},
#   {'ns': 0, 'exists': '', '*': 'SAP SE'},
#   {'ns': 0, 'exists': '', '*': 'Sage Publications'},
#   {'ns': 0, 'exists': '', '*': 'Seattle, Washington'},
#   {'ns': 0, 'exists': '', '*': 'Sequoia Capital'},
#   {'ns': 0, 'exists': '', '*': 'Silver Row'},
#   {'ns': 0, 'exists': '', '*': 'Simon P. Eggertsen Sr. House'},
#   {'ns': 0, 'exists': '', '*': 'Smith Fieldhouse'},
#   {'ns': 0, 'exists': '', '*': 'Sogosurvey'},
#   {'ns': 0, 'exists': '', '*': 'Stadium of Fire'},
#   {'ns': 0, 'exists': '', '*': 'Startup Candy Factory'},
#   {'ns': 0, 'exists': '', '*': 'Sundance Resort'},
#   {'ns': 0, 'exists': '', '*': 'Sunfall Festival'},
#   {'ns': 0,
#    'exists': '',
#    '*': "Superintendent's Residence at the Utah State Hospital"},
#   {'ns': 0, 'exists': '', '*': 'Survata'},
#   {'ns': 0, 'exists': '', '*': 'SurveyMonkey'},
#   {'ns': 0, 'exists': '', '*': 'Survey data collection'},
#   {'ns': 0, 'exists': '', '*': 'The Ryde'},
#   {'ns': 0, 'exists': '', '*': 'The Shops at Riverwoods'},
#   {'ns': 0, 'exists': '', '*': 'The Universe (student newspaper)'},
#   {'ns': 0, 'exists': '', '*': 'Thomas N. Taylor House'},
#   {'ns': 0, 'exists': '', '*': 'Three Angels Broadcasting Network'},
#   {'ns': 0, 'exists': '', '*': 'Timpview High School'},
#   {'ns': 0, 'exists': '', '*': 'Typeform (service)'},
#   {'ns': 0, 'exists': '', '*': 'U.S. Route 189'},
#   {'ns': 0, 'exists': '', '*': 'U.S. Route 89 in Utah'},
#   {'ns': 0, 'exists': '', '*': 'Uinta National Forest'},
#   {'ns': 0, 'exists': '', '*': 'United States'},
#   {'ns': 0, 'exists': '', '*': 'University of North Carolina at Chapel Hill'},
#   {'ns': 0, 'exists': '', '*': 'Utah County, Utah'},
#   {'ns': 0, 'exists': '', '*': 'Utah Lake'},
#   {'ns': 0, 'exists': '', '*': 'Utah Lake State Park'},
#   {'ns': 0, 'exists': '', '*': 'Utah Starzz (WPSL)'},
#   {'ns': 0, 'exists': '', '*': 'Utah State Hospital'},
#   {'ns': 0, 'exists': '', '*': 'Utah State Route 114'},
#   {'ns': 0, 'exists': '', '*': 'Utah State Route 265'},
#   {'ns': 0, 'exists': '', '*': 'Utah Transit Authority'},
#   {'ns': 0, 'exists': '', '*': 'Utah Valley'},
#   {'ns': 0, 'exists': '', '*': 'Utah Valley Convention Center'},
#   {'ns': 0, 'exists': '', '*': 'Utah Valley Express'},
#   {'ns': 0, 'exists': '', '*': 'Utah Valley Hospital'},
#   {'ns': 0, 'exists': '', '*': 'Utah Valley Marathon'},
#   {'ns': 0, 'exists': '', '*': 'Velour Live Music Gallery'},
#   {'ns': 0, 'exists': '', '*': 'Vivint'},
#   {'ns': 0, 'exists': '', '*': 'Wasatch-Cache National Forest'},
#   {'ns': 0, 'exists': '', '*': 'Wasatch Front'},
#   {'ns': 0, 'exists': '', '*': 'William D. Alexander House'},
#   {'ns': 0, 'exists': '', '*': 'William D. Roberts House'},
#   {'ns': 0, 'exists': '', '*': 'William H. Ray House'},
#   {'ns': 0, 'exists': '', '*': 'Y Mountain'},
#   {'ns': 0, 'exists': '', '*': 'Zoho Survey'},
#   {'ns': 0, '*': 'Agel Enterprises'},
#   {'ns': 0, '*': 'Independence High School (Utah)'},
#   {'ns': 0, '*': 'K43JV'},
#   {'ns': 4, 'exists': '', '*': 'Wikipedia:Link rot'},
#   {'ns': 11, 'exists': '', '*': 'Template talk:Provo, Utah'},
#   {'ns': 11, 'exists': '', '*': 'Template talk:Survey data collection'}],
#  'templates': [{'ns': 10, 'exists': '', '*': 'Template:Infobox company'},
#   {'ns': 10, 'exists': '', '*': 'Template:Infobox'},
#   {'ns': 10, 'exists': '', '*': 'Template:Longitem'},
#   {'ns': 10, 'exists': '', '*': 'Template:Br separated entries'},
#   {'ns': 10, 'exists': '', '*': 'Template:Start date and age'},
#   {'ns': 10, 'exists': '', '*': 'Template:Yesno'},
#   {'ns': 10, 'exists': '', '*': 'Template:Years or months ago'},
#   {'ns': 10, 'exists': '', '*': 'Template:Comma separated entries'},
#   {'ns': 10, 'exists': '', '*': 'Template:Template other'},
#   {'ns': 10, 'exists': '', '*': 'Template:Main other'},
#   {'ns': 10, 'exists': '', '*': 'Template:Reflist'},
#   {'ns': 10, 'exists': '', '*': 'Template:Cite news'},
#   {'ns': 10, 'exists': '', '*': 'Template:Cite web'},
#   {'ns': 10, 'exists': '', '*': 'Template:Dead link'},
#   {'ns': 10, 'exists': '', '*': 'Template:Fix'},
#   {'ns': 10, 'exists': '', '*': 'Template:Category handler'},
#   {'ns': 10, 'exists': '', '*': 'Template:Fix/category'},
#   {'ns': 10, 'exists': '', '*': 'Template:Cite book'},
#   {'ns': 10, 'exists': '', '*': 'Template:Commons category'},
#   {'ns': 10, 'exists': '', '*': 'Template:Commons'},
#   {'ns': 10, 'exists': '', '*': 'Template:Sister project'},
#   {'ns': 10, 'exists': '', '*': 'Template:Side box'},
#   {'ns': 10, 'exists': '', '*': 'Template:If then show'},
#   {'ns': 10, 'exists': '', '*': 'Template:Official website'},
#   {'ns': 10, 'exists': '', '*': 'Template:Survey data collection'},
#   {'ns': 10, 'exists': '', '*': 'Template:Navbox'},
#   {'ns': 10, 'exists': '', '*': 'Template:Provo, Utah'},
#   {'ns': 828, 'exists': '', '*': 'Module:Infobox'},
#   {'ns': 828, 'exists': '', '*': 'Module:Navbar'},
#   {'ns': 828, 'exists': '', '*': 'Module:InfoboxImage'},
#   {'ns': 828, 'exists': '', '*': 'Module:Separated entries'},
#   {'ns': 828, 'exists': '', '*': 'Module:TableTools'},
#   {'ns': 828, 'exists': '', '*': 'Module:Arguments'},
#   {'ns': 828, 'exists': '', '*': 'Module:Check for unknown parameters'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1/Configuration'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1/Whitelist'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1/Utilities'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1/Date validation'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1/Identifiers'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1/COinS'},
#   {'ns': 828, 'exists': '', '*': 'Module:Citation/CS1/styles.css'},
#   {'ns': 828, 'exists': '', '*': 'Module:Unsubst'},
#   {'ns': 828, 'exists': '', '*': 'Module:Category handler'},
#   {'ns': 828, 'exists': '', '*': 'Module:Yesno'},
#   {'ns': 828, 'exists': '', '*': 'Module:Category handler/data'},
#   {'ns': 828, 'exists': '', '*': 'Module:Category handler/config'},
#   {'ns': 828, 'exists': '', '*': 'Module:Category handler/shared'},
#   {'ns': 828, 'exists': '', '*': 'Module:Category handler/blacklist'},
#   {'ns': 828, 'exists': '', '*': 'Module:Namespace detect/data'},
#   {'ns': 828, 'exists': '', '*': 'Module:Namespace detect/config'},
#   {'ns': 828, 'exists': '', '*': 'Module:Side box'},
#   {'ns': 828, 'exists': '', '*': 'Module:WikidataIB'},
#   {'ns': 828, 'exists': '', '*': 'Module:Complex date'},
#   {'ns': 828, 'exists': '', '*': 'Module:I18n/complex date'},
#   {'ns': 828, 'exists': '', '*': 'Module:Ordinal'},
#   {'ns': 828, 'exists': '', '*': 'Module:Roman'},
#   {'ns': 828, 'exists': '', '*': 'Module:ISOdate'},
#   {'ns': 828, 'exists': '', '*': 'Module:DateI18n'},
#   {'ns': 828, 'exists': '', '*': 'Module:I18n/date'},
#   {'ns': 828, 'exists': '', '*': 'Module:Calendar'},
#   {'ns': 828, 'exists': '', '*': 'Module:WikidataIB/nolinks'},
#   {'ns': 828, 'exists': '', '*': 'Module:String'},
#   {'ns': 828, 'exists': '', '*': 'Module:Official website'},
#   {'ns': 828, 'exists': '', '*': 'Module:URL'},
#   {'ns': 828, 'exists': '', '*': 'Module:Navbox'}],
#  'images': ['Qualtrics_logo.svg', 'Commons-logo.svg'],
#  'externallinks': ['http://usatoday30.usatoday.com/MONEY/usaedition/2012-08-28-Efficient-Small-Business-Ecommerce_CV_U.htm',
#   'https://blogs.wsj.com/venturecapital/2012/05/15/qualtrics-taps-accel-sequoia-for-first-ever-vc-round/',
#   'http://www.qualtrics.com',
#   'https://xodata.com/press-release/',
#   'https://www.cbinsights.com/blog/venture-capital-peer-rankings/',
#   'https://techcrunch.com/2011/05/25/top-10-vc-firms-investorrank/',
#   'https://techcrunch.com/2012/05/15/qualtrics-raises-70m-accel-sequoia/',
#   'http://www.businessweek.com/articles/2014-09-24/how-qualtrics-turned-online-surveys-into-a-1-billion-business',
#   'https://www.crunchbase.com/organization/qualtrics',
#   'https://www.crunchbase.com/funding_round/qualtrics-series-c--dc3c0897',
#   'https://www.sec.gov/Archives/edgar/data/1747748/000162828018012674/qualtricss-1.htm',
#   'https://www.forbes.com/cloud100/',
#   'https://www.forbes.com/companies/qualtrics/',
#   'http://www.mrweb.com/drno/news22721.htm',
#   'https://web.archive.org/web/20160625031937/https://finance.yahoo.com/news/qualtrics-acquires-y-combinator-funded-120000831.html',
#   'https://finance.yahoo.com/news/qualtrics-acquires-y-combinator-funded-120000831.html',
#   'https://www.forbes.com/sites/alexkonrad/2018/04/12/qualtrics-acquires-delighted/#4096aec927a2',
#   'https://www.verdict.co.uk/cards-international/news/tango-card-partners-qualtrics-gift-card-management/',
#   'https://www.cnbc.com/2018/11/11/sap-is-buying-qualtrics-sources-say.html',
#   'https://web.archive.org/web/20070105010639/http://marketing.byu.edu/download/marketingresearch/HMR%20Chapter%2011.pdf',
#   'http://ilin.asee.org/Conference2008/SESSIONS/A%20Retrospective%20Study%20of%20Skills%20Traits%20Influences%20and%20S.pdf',
#   'http://db.jhuccp.org/ics-wpd/exec/icswppro.dll?BU=http://db.jhuccp.org/ics-wpd/exec/icswppro.dll&QF0=DocNo&QI0=322399&TN=Popline&AC=QBE_QUERY&MR=30%25DL=1&&RL=1&&RF=LongRecordDisplay&DF=LongRecordDisplay',
#   'http://works.bepress.com/cgi/viewcontent.cgi?article=1000&context=ken_brunson',
#   'https://books.google.com/books?id=0t1E-oihkDkC&printsec=frontcover#v=onepage&q=qualtrics&f=false',
#   'https://www.amazon.com/Essentials-Marketing-Research-Qualtrics-Card/dp/1439047545',
#   'https://www.amazon.com/Business-Research-Methods-Qualtrics-Printed/dp/1111826927',
#   'https://www.amazon.com/Modern-Marketing-Research-Concepts-Qualtrics/dp/1133188966/ref=sr_1_2?s=books&ie=UTF8&qid=1340716864&sr=1-2&keywords=feinberg,+kinnear,+taylor',
#   'https://www.amazon.com/Marketing-Research-Qualtrics-Printed-Access/dp/1439041393',
#   'http://markets.businessinsider.com/news/stocks/Qualtrics-Simplifies-Closing-the-Employee-Experience-Gap-With-Powerful-New-Methodology-1002283007',
#   'http://www.qualtrics.com/',
#   'https://www.qualtrics.com'],
#  'sections': [{'toclevel': 1,
#    'level': '2',
#    'line': 'History',
#    'number': '1',
#    'index': '1',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 2395,
#    'anchor': 'History'},
#   {'toclevel': 2,
#    'level': '3',
#    'line': 'Funding & Valuation',
#    'number': '1.1',
#    'index': '2',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 2407,
#    'anchor': 'Funding_&_Valuation'},
#   {'toclevel': 2,
#    'level': '3',
#    'line': 'Filing for IPO',
#    'number': '1.2',
#    'index': '3',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 4373,
#    'anchor': 'Filing_for_IPO'},
#   {'toclevel': 2,
#    'level': '3',
#    'line': 'Ranking',
#    'number': '1.3',
#    'index': '4',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 5225,
#    'anchor': 'Ranking'},
#   {'toclevel': 2,
#    'level': '3',
#    'line': 'Revenue',
#    'number': '1.4',
#    'index': '5',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 5632,
#    'anchor': 'Revenue'},
#   {'toclevel': 2,
#    'level': '3',
#    'line': 'Acquisitions',
#    'number': '1.5',
#    'index': '6',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 5981,
#    'anchor': 'Acquisitions'},
#   {'toclevel': 2,
#    'level': '3',
#    'line': 'Acquisition by SAP SE',
#    'number': '1.6',
#    'index': '7',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 7698,
#    'anchor': 'Acquisition_by_SAP_SE'},
#   {'toclevel': 1,
#    'level': '2',
#    'line': 'Research',
#    'number': '2',
#    'index': '8',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 8624,
#    'anchor': 'Research'},
#   {'toclevel': 1,
#    'level': '2',
#    'line': 'References',
#    'number': '3',
#    'index': '9',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 12726,
#    'anchor': 'References'},
#   {'toclevel': 1,
#    'level': '2',
#    'line': 'External links',
#    'number': '4',
#    'index': '10',
#    'fromtitle': 'Qualtrics',
#    'byteoffset': 12754,
#    'anchor': 'External_links'}],
#  'parsewarnings': [],
#  'displaytitle': 'Qualtrics',
#  'iwlinks': [{'prefix': 'commons',
#    'url': 'https://commons.wikimedia.org/wiki/Category:Qualtrics',
#    '*': 'commons:Category:Qualtrics'}],
#  'properties': [{'name': 'wikibase_item', '*': 'Q7268803'}]}

# %%
type(DATA)
DATA['parse']['text']['*']
# Out:
# '<div class="mw-parser-output"><table class="infobox vcard" style="width:22em"><caption class="fn org">Qualtrics International Inc.</caption><tbody><tr><td colspan="2" class="logo" style="text-align:center"><a href="/wiki/File:Qualtrics_logo.svg" class="image"><img alt="Qualtrics logo.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Qualtrics_logo.svg/200px-Qualtrics_logo.svg.png" decoding="async" width="200" height="72" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Qualtrics_logo.svg/300px-Qualtrics_logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Qualtrics_logo.svg/400px-Qualtrics_logo.svg.png 2x" data-file-width="150" data-file-height="54" /></a></td></tr><tr><th scope="row" style="padding-right:0.5em;"><div style="padding:0.1em 0;line-height:1.2em;"><a href="/wiki/List_of_legal_entity_types_by_country" title="List of legal entity types by country">Type</a></div></th><td class="category" style="line-height:1.35em;"><a href="/wiki/Private_Company" class="mw-redirect" title="Private Company">Private</a></td></tr><tr><th scope="row" style="padding-right:0.5em;">Industry</th><td class="category" style="line-height:1.35em;">Experience Management</td></tr><tr><th scope="row" style="padding-right:0.5em;">Founded</th><td style="line-height:1.35em;">2002<span class="noprint">&#59;&#32;17&#160;years ago</span><span style="display:none">&#160;(<span class="bday dtstart published updated">2002</span>)</span></td></tr><tr><th scope="row" style="padding-right:0.5em;">Founders</th><td class="agent" style="line-height:1.35em;">Scott M. Smith<br />Ryan Smith<br />Jared Smith<br />Stuart Orgill</td></tr><tr><th scope="row" style="padding-right:0.5em;">Headquarters</th><td class="label" style="line-height:1.35em;"><a href="/wiki/Provo,_Utah" title="Provo, Utah">Provo, Utah</a>, <a href="/wiki/United_States" title="United States">U.S.</a><br /> <a href="/wiki/Seattle,_Washington" class="mw-redirect" title="Seattle, Washington">Seattle, Washington</a>, U.S.<br />Other offices: Dublin, Ireland<br />Sydney, NSW, Australia<br />London, England, U.K.<br />Munich, Germany<br />Melbourne, Vic, Australia<br />Washington, D.C., U.S.<br />Dallas, Texas, U.S.</td></tr><tr><th scope="row" style="padding-right:0.5em;"><div style="padding:0.1em 0;line-height:1.2em;">Key people</div></th><td class="agent" style="line-height:1.35em;"><b>Ryan Smith,</b> CEO<sup id="cite_ref-USAToday2012Scott_1-0" class="reference"><a href="#cite_note-USAToday2012Scott-1">&#91;1&#93;</a></sup> Co-founder, <b>Scott M. Smith,</b> Co-founder, <b>Jared Smith,</b> Co-founder, and <b>Stuart Orgill,</b> Co-founder</td></tr><tr><th scope="row" style="padding-right:0.5em;">Products</th><td style="line-height:1.35em;">Qualtrics XM Platform, Qualtrics Research Core, Customer Experience, Employee Experience, Product Experience, Brand Experience, Online Sample</td></tr><tr><th scope="row" style="padding-right:0.5em;"><div style="padding:0.1em 0;line-height:1.2em;">Number of employees</div></th><td style="line-height:1.35em;">2,100+</td></tr><tr><th scope="row" style="padding-right:0.5em;">Website</th><td style="line-height:1.35em;"><a rel="nofollow" class="external text" href="http://www.qualtrics.com/">Qualtrics.com</a></td></tr></tbody></table>\n<p><b>Qualtrics</b> is a privately held experience management company, with co-headquarters in <a href="/wiki/Provo,_Utah" title="Provo, Utah">Provo, Utah</a> and <a href="/wiki/Seattle,_Washington" class="mw-redirect" title="Seattle, Washington">Seattle, Washington</a>, in the United States. The company was founded in 2002 by Scott M. Smith, Ryan Smith, Jared Smith and Stuart Orgill.<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">&#91;2&#93;</a></sup>\n</p><p>Qualtrics is a subscription software for collecting and analyzing data<sup id="cite_ref-USAToday2012Scott_1-1" class="reference"><a href="#cite_note-USAToday2012Scott-1">&#91;1&#93;</a></sup> for market research, customer satisfa ...

# %%
from bs4 import BeautifulSoup

def get_info(company_name):
    industry = ''
    
    session = requests.Session()
    url = "https://en.wikipedia.org/w/api.php"

    PARAMS = {
        'action': "parse",
        'page': company_name,
        'format': "json"
    }
    #print (PARAMS)
    R = S.get(url=URL, params=PARAMS)
    data = R.json()
    text = data['parse']['text']['*']

    soup = BeautifulSoup(text, "lxml")
    contents = list(soup.stripped_strings)
    
    #print (contents)
    
    #official_company_name = contents[0]
    
    if "Industry" in contents:
        industry = contents[contents.index("Industry") + 1]
        
    
    #if "Website" in contents:
    #    website = contents[contents.index("Website") + 1]

    return (company_name, industry)

# %% [markdown]
# ## METHOD ONLY GETS FIRST INDUSTRY

# %%
get_info('Qualtrics')
# Out:
# ('Qualtrics', 'Experience Management')

# %%
get_info('Facebook')
# Out:
# ('Facebook', 'Internet')

# %%
get_info('Verizon Media')
# Out:
# ('Verizon Media', 'Internet')

# %%
x = DATA['parse']['text']['*']
soup = BeautifulSoup(x, "lxml")
list(soup.children)
PARAMS
#soup('body')
# Out:
# {'action': 'parse', 'page': 'Qualtrics', 'format': 'json'}

# %%
#import re
#industry = re.search(r'>Industry</th><td class="category" style="line-height:1.35em;">(\s)</td></tr><tr><th',x)
#industry = re.findall(r'Industry',x)

#print(industry)

# %%
session = requests.Session()
url = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    'action': "parse",
    'page': 'Facebook',
    'format': "json",
    'section': '0'
}
    #print (PARAMS)
R = S.get(url=URL, params=PARAMS)
data = R.json()
text = data['parse']['text']['*']
text
soup = BeautifulSoup(text, "lxml")
soup.prettify()
titles,content = [],[]
for item in soup('th'):
    titles.append(item.text)
    #print (item)
#print(len(titles))
for item in soup('td')[1:]:
    content.append(item.text)
    #print (item)
#print(len(content))
print (content[0])
list(zip(titles,content))
#    contents = list(soup.stripped_strings)
# Out:
# Mark Zuckerberg's profile (viewed from the login page)
# [('Type of business',
#   "Mark Zuckerberg's profile (viewed from the login page)"),
#  ('Type of site', 'Public'),
#  ('Available\xa0in', 'Social networking service'),
#  ('Traded\xa0as', 'Multilingual (140)'),
#  ('Founded',
#   'NASDAQ:\xa0FB (Class A)NASDAQ-100 componentS&P 100 componentS&P 500 component'),
#  ('Headquarters',
#   'February\xa04, 2004; 14 years ago\xa0(2004-02-04) in Cambridge, Massachusetts[1]'),
#  ('Coordinates',
#   '1 Hacker Way(aka 1601 Willow Road)Menlo Park, California, U.S.'),
#  ('Area\xa0served',
#   '37°29′05″N 122°08′54″W\ufeff / \ufeff37.4848°N 122.1484°W\ufeff / 37.4848; -122.1484Coordinates: 37°29′05″N 122°08′54″W\ufeff / \ufeff37.4848°N 122.1484°W\ufeff / 37.4848; -122.1484'),
#  ('Founder(s)',
#   'United States (2004–present)Worldwide, except blocking countries (2005–present)'),
#  ('Key\xa0people',
#   'Mark ZuckerbergEduardo SaverinAndrew McCollumDustin MoskovitzChris Hughes'),
#  ('Industry',
#   'Mark Zuckerberg(Chairman and CEO)Sheryl Sandberg(COO)David Wehner(CFO)Mike Schroepfer(CTO)Chris Cox(CPO)'),
#  ('Products', 'Internet'),
#  ('Revenue', 'MessengerWatch'),
#  ('Operating income', ' US$40.653 billion (2017)[2]'),
#  ('Net income', ' US$20.203 billion (2017)[2]'),
#  ('Total assets', ' US$15.934 billion (2017)[2]'),
#  ('Total equity', ' US$84.524 billion (2017)[2]'),
#  ('Employees', ' US$74.347 billion (2017)[2]'),
#  ('Subsidiaries', '30,275 (June 30, 2018)[3]'),
#  ('Website', 'InstagramWhatsAppOculus VR'),
#  ('Alexa rank', 'www.facebook.comwww.fb.comfacebookcorewwwi.onion(Dark web)'),
#  ('Registration', ' 3 (January 2019)[update][4]'),
#  ('Users', 'Required'),
#  ('Current\xa0status',
#   ' 2.2 billion monthly active users (January 2018)[update]'),
#  ('Written\xa0in', 'Active')]
