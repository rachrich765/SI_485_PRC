# %%
 
import pandas as pd
import requests
import textract
import os
from bs4 import BeautifulSoup
import time
import csv
import numpy as np

# %%
maine = 'https://www.maine.gov/ag/consumer/identity_theft/' #URL of Main webpage
code = requests.get(maine)
plain = code.text
s = BeautifulSoup(plain, "html.parser") #assings the HTML to the varriable S
# print(s)

# %%
year_url = '' #creates URL string
for x in s('ul', {'class':"plain"}): #iterates through the neccisary HTML to get needed href
    for item in x('a'):
#     	print(item)   
        if item.get('href') == '../../docs/Data-Breach-Spreadsheet.xlsx':
            year_url = item.get('href') #retrieves and asisngs needed content (str) to year_url varialbe
# print(year_url)

# %%
core_year_url = 'https://www.maine.gov/ag'

# %%
year_url = year_url[5:] #index needed part of string for URL
# print(year_urls)

# %%
final_url = core_year_url + year_url
print(final_url)
# Out:
# https://www.maine.gov/ag/docs/Data-Breach-Spreadsheet.xlsx

# %%
#calls request to on URL
resp = requests.get(final_url)

#opens and creates .xls 
output = open('Maine.xls', 'wb')

#wirtes in new xls content from request
output.write(resp.content)
output.close()

# %%
df = pd.read_excel('Maine.xls')  #test
# df.head(10)

# %%
headers = df.iloc[0] #takes first row (needed hearders)

new_df  = pd.DataFrame(df.values[1:], columns=headers) #creates new pd data frame with the proper headers and fills data
new_df.head(15)
# Out:
# 0                Company Whose      Data Was Breached  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Whole Foods Market Group, Inc., 550 Bowie Stre...
# 6   LJCooper Capital Management, LLC d/b/a LJCoope...
# 7   University of Maine, 46 University Drive, Augu...
# 8   Star Title Partners of Palm Harbor, LLC, 30522...
# 9   Cenera Funding, Inc., 3600 Benbrook Highway, F...
# 10  Fifth Third Bank, 38 Fountain Square Plaza, Ci...
# 11                                              Net32
# 12  TravisMathew LLC, 15202 Graham Street, Hunting...
# 13  Heartland Hotel Corporation, 4403 First Ave., ...
# 14  STL International, Inc., d/b/a Teeter, 9902 16...
#
# 0                         Company Contact Information  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                None
# 6                                                None
# 7   Nina R. Lavoie, Sr. Associate Counsel, 621-344...
# 8   Anne Cordell, General Manager & Counsel, 813-3...
# 9   Mark Browning, CEO 817-546-0362; mbrowning@cen...
# 10  Robert Howell, Privacy Compliance Mgr, 513-358...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
#
# 0         Attorney                   (If Represented)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Craig Hoffman, Partner, Baker Hostetler LLP, 3...
# 6   R. David Lane, Marshall Dennehey Warner Colema...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Michael Gottlieb, Boes Schiller Flexner, 202-2...
# 12  Andreas Kaltsounis, Baker & Hostetler LLP, 206...
# 13  William Daugherty, Baker & Hostetler LLP, 713-...
# 14  Alyssa Watzman, Lewis Brisbois Bisgaard & Smit...
#
# 0                        Date of Breach Date of Notification  \
# 0                                   NaN                  NaN
# 1                                   NaN                  NaN
# 2                                   NaN                  NaN
# 3                                   NaN                  NaN
# 4                                   NaN                  NaN
# 5         8/3/2018 (discovered 10/2/18)  2018-10-31 00:00:00
# 6                   2018-09-18 00:00:00  2018-10-29 00:00:00
# 7                   Discovered 10/23/18  2018-10-27 00:00:00
# 8                   2018-06-04 00:00:00  2018-10-26 00:00:00
# 9                   2018-09-29 00:00:00  2018-10-25 00:00:00
# 10  8/6/18-8/31/18 (discovered 8/29/18)  2018-10-26 00:00:00
# 11                    9/22/18 - 9/25/18  2018-10-25 00:00:00
# 12                      8/13/18-9/24/18  2018-10-25 00:00:00
# 13                    Unknown - 9/25/18  2018-10-25 00:00:00
# 14                      4/11/18-9/13/18  2018-10-25 00:00:00
#
# 0                                 Type of Information  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Name or other personal identifier in combinati...
# 6   Name or other personal identifier in combinati...
# 7                         Personal data including SSN
# 8   Name or other personal identifier in combinati...
# 9   Name or other personal identifier in combinati...
# 10  Name or other personal identifier in combinati...
# 11  Personal information relating to Net32 orders ...
# 12  Name or other personal identifier in combinati...
# 13  Name or other personal identifier in combinati...
# 14  Name or other personal identifier in combinati...
#
# 0  Number of Maine Residents Affected
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                   3
# 6                                   1
# 7                                  32
# 8                                   4
# 9                                   1
# 10                                  1
# 11                                 25
# 12                                 10
# 13                                  1
# 14                                 68

# %%
#replaces spaces with _ for easier use to call column names
new_df.columns = [c.replace(' ', '_') for c in new_df.columns]

# %%
# new_df.columns #checks column headers

# %%
#gets rid of files under "Company_Whose______Data_Was_Breached" column with the value "Nan"

new_df = new_df[new_df.Company_Whose______Data_Was_Breached==new_df.Company_Whose______Data_Was_Breached].reset_index(drop = True)

# %%
new_df.head()
# Out:
#                 Company_Whose______Data_Was_Breached  \
# 0  Whole Foods Market Group, Inc., 550 Bowie Stre...
# 1  LJCooper Capital Management, LLC d/b/a LJCoope...
# 2  University of Maine, 46 University Drive, Augu...
# 3  Star Title Partners of Palm Harbor, LLC, 30522...
# 4  Cenera Funding, Inc., 3600 Benbrook Highway, F...
#
#                          Company_Contact_Information  \
# 0                                               None
# 1                                               None
# 2  Nina R. Lavoie, Sr. Associate Counsel, 621-344...
# 3  Anne Cordell, General Manager & Counsel, 813-3...
# 4  Mark Browning, CEO 817-546-0362; mbrowning@cen...
#
#          Attorney___________________(If_Represented)  \
# 0  Craig Hoffman, Partner, Baker Hostetler LLP, 3...
# 1  R. David Lane, Marshall Dennehey Warner Colema...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                   Date_of_Breach Date_of_Notification  \
# 0  8/3/2018 (discovered 10/2/18)  2018-10-31 00:00:00
# 1            2018-09-18 00:00:00  2018-10-29 00:00:00
# 2            Discovered 10/23/18  2018-10-27 00:00:00
# 3            2018-06-04 00:00:00  2018-10-26 00:00:00
# 4            2018-09-29 00:00:00  2018-10-25 00:00:00
#
#                                  Type_of_Information  \
# 0  Name or other personal identifier in combinati...
# 1  Name or other personal identifier in combinati...
# 2                        Personal data including SSN
# 3  Name or other personal identifier in combinati...
# 4  Name or other personal identifier in combinati...
#
#   Number_of_Maine_Residents_Affected
# 0                                  3
# 1                                  1
# 2                                 32
# 3                                  4
# 4                                  1
